# %%
import os
import wanglijun as w

# %%
w.show_source(os.path.expanduser)
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN"
#    "http://www.w3.org/TR/html4/strict.dtd">
# <!--
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2022 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# -->
# <html>
# <head>
#   <title></title>
#   <meta http-equiv="content-type" content="text/html; charset=None">
#   <style type="text/css">
# /*
# generated by Pygments <https://pygments.org/>
# Copyright 2006-2022 by the Pygments team.
# Licensed under the BSD license, see LICENSE for details.
# */
# pre { line-height: 125%; }
# td.linenos .normal { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# span.linenos { color: inherit; background-color: transparent; padding-left: 5px; padding-right: 5px; }
# td.linenos .special { color: #000000; background-color: #ffffc0; padding-left: 5px; padding-right: 5px; }
# ...

# %%
w._style
w._output_fmt
# Out:
# 'html'

# %%
match 1,2:
    case _,2:
        print("ok")
# Out:
# ok

# %%
from show import *

def f(a:int):
    def g()->int:
        return a
    return g



for x in fetch_attrs(f(23),skip_none=True):
    print(x)
# Out:
# Attr(name='__name__', type='str', value='g')
# Attr(name='__module__', type='str', value='__main__')
# Attr(name='__class__', type='type', value='function')
# Attr(name='__dict__', type='dict', value={})
# Attr(name='__sizeof__', type='int', value=128)
# Attr(name='__code__', type='code', value='g')
# Attr(name='__annotations__', type='dict', value={'return': <class 'int'>})
# Attr(name='__closure__', type='tuple', value=[23])
# Attr(name='__globals__', type='dict', value='52 vars')
# Attr(name='__builtins__', type='dict', value='158 vars')

# %%
dir(type(fetch_attrs))
# Out:
# ['__annotations__',
#  '__builtins__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
from dataclasses import dataclass
@dataclass
class A:
    v:int

# %%
a = A(23)

# %%
a.v = 34

# %%
a
# Out:
# A(v=34)

# %%
import dataclasses

# %%
dataclasses.replace()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 dataclasses.replace()
#
# TypeError: replace() missing 1 required positional argument: 'obj'
